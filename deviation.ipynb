# %%
import numpy as np
from scipy.signal import correlate2d
master = np.loadtxt("mel_spectrogram.csv", delimiter=",")
M, N = master.shape
submatrix_files = [
    "submatrix_3.csv",
    "submatrix_3_variant_1.csv",
    "submatrix_3_variant_2.csv",
    "submatrix_3_variant_3.csv",
    "submatrix_3_variant_4.csv"
]
print("Master matrix shape:", master.shape)
for file in submatrix_files:
    sub = np.loadtxt(file, delimiter=",")
    m, n = sub.shape
    sub_norm = sub / np.linalg.norm(sub)
    master_norm = master / np.linalg.norm(master)
    corr = correlate2d(master_norm, sub_norm, mode="valid")
    i, j = np.unravel_index(np.argmax(corr), corr.shape)
    best_score = corr[i, j]
    deviation_percent = (1 - best_score) * 100
    print("\nFile:", file)
    print("Start Row :", i)
    print("End Row   :", i + m - 1)
    print("Start Col :", j)
    print("End Col   :", j + n - 1)
    print("Similarity score :", best_score)
    print("Deviation (%)    :", deviation_percent)
# Out:
# Master matrix shape: (128, 95)
#
# File: submatrix_3.csv
# Start Row : 0
# End Row   : 127
# Start Col : 17
# End Col   : 56
# Similarity score : 0.654802651357211
# Deviation (%)    : 34.519734864278895
#
# File: submatrix_3_variant_1.csv
# Start Row : 0
# End Row   : 127
# Start Col : 17
# End Col   : 56
# Similarity score : 0.6548003709063368
# Deviation (%)    : 34.51996290936632
#
# File: submatrix_3_variant_2.csv
# Start Row : 0
# End Row   : 127
# Start Col : 17
# End Col   : 56
# Similarity score : 0.6545847951107293
# Deviation (%)    : 34.54152048892707
#
# File: submatrix_3_variant_3.csv
# Start Row : 0
# End Row   : 127
# Start Col : 17
# End Col   : 56
# Similarity score : 0.6492935284993859
# Deviation (%)    : 35.070647150061404
#
# File: submatrix_3_variant_4.csv
# Start Row : 0
# End Row   : 127
# Start Col : 17
# End Col   : 56
# Similarity score : 0.6333629621382524
# Deviation (%)    : 36.663703786174764
